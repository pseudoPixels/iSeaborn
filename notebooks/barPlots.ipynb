# %%
import seaborn as sns
from bokehBorn.categorical import barplot
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
tips = sns.load_dataset("tips")

barplot(x="day", y="total_bill", data=tips, orient="v")
# Out:
# ['Thur', 'Fri', 'Sat', 'Sun']
# [17.68274194 17.15157895 20.44137931 21.41      ]
#   <div class="bk-root" id="3aba62e6-332f-4a62-9501-ef1a182ffe36" data-root-id="1002"></div>

# %%
barplot(x="tip", y="day", data=tips)
# Out:
# ['Thur', 'Fri', 'Sat', 'Sun']
# [2.77145161 2.73473684 2.99310345 3.25513158]
#   <div class="bk-root" id="64d78e33-0884-4a41-b37a-093ecd66e5e8" data-root-id="1101"></div>
